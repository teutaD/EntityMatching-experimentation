# %% [markdown]
#  Datasets are in Drive ([assets folder](https://drive.google.com/drive/folders/1ZVjLNbd2LriFEqVV_kj8A4VuNHGeTkD-?usp=drive_link)). Please create a shortcut from this folder to "MyDrive".

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Testing [OntologyAligners](https://github.com/sciknoworg/OntoAligner) KG Embedding for entity matching

# %%
# !pip install ontoaligner
# Out:
# Requirement already satisfied: ontoaligner in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Collecting argparse (from ontoaligner)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: bitsandbytes<1.0.0,>=0.45.1 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (0.49.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (4.0.0)
# Requirement already satisfied: huggingface-hub<0.35.0,>=0.34.4 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (0.34.6)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (1.26.4)
# Requirement already satisfied: openai==1.56.0 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (1.56.0)
# Requirement already satisfied: owlready2==0.44 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (0.44)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (2.2.2)
# Requirement already satisfied: pathlib in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (1.0.1)
# Requirement already satisfied: py-stringmatching in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (0.4.6)
# Requirement already satisfied: pykeen==1.11.1 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (1.11.1)
# Requirement already satisfied: rank_bm25==0.2.2 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (0.2.2)
# Requirement already satisfied: rapidfuzz==3.5.2 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (3.5.2)
# Requirement already satisfied: rdflib==7.1.1 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (7.1.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (1.6.1)
# Requirement already satisfied: sentence-transformers<6.0.0,>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (5.2.0)
# Requirement already satisfied: torch<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (2.9.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (4.67.1)
# Requirement already satisfied: transformers<5.0.0,>=4.56.0 in /usr/local/lib/python3.12/dist-packages (from ontoaligner) (4.57.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.56.0->ontoaligner) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.56.0->ontoaligner) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.56.0->ontoaligner) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.56.0->ontoaligner) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai==1.56.0->ontoaligner) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai==1.56.0->ontoaligner) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai==1.56.0->ontoaligner) (4.15.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.6.7)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (1.16.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (8.3.1)
# Requirement already satisfied: click_default_group in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (1.2.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (2.32.4)
# Requirement already satisfied: optuna>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (4.7.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.9.0)
# Requirement already satisfied: more_click in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.1.3)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (10.8.0)
# Requirement already satisfied: pystow>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.7.15)
# Requirement already satisfied: docdata>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.0.5)
# Requirement already satisfied: class_resolver>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.7.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (6.0.3)
# Requirement already satisfied: torch_max_mem>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.1.4)
# Requirement already satisfied: torch-ppr>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from pykeen==1.11.1->ontoaligner) (0.0.8)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib==7.1.1->ontoaligner) (3.3.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes<1.0.0,>=0.45.1->ontoaligner) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<0.35.0,>=0.34.4->ontoaligner) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<0.35.0,>=0.34.4->ontoaligner) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<0.35.0,>=0.34.4->ontoaligner) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->ontoaligner) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->ontoaligner) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->ontoaligner) (2025.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0.0,>=2.8.0->ontoaligner) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.56.0->ontoaligner) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.56.0->ontoaligner) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.56.0->ontoaligner) (0.7.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->ontoaligner) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->ontoaligner) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->ontoaligner) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->ontoaligner) (0.70.16)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->ontoaligner) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->ontoaligner) (3.6.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai==1.56.0->ontoaligner) (3.11)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (3.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.56.0->ontoaligner) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==1.56.0->ontoaligner) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.56.0->ontoaligner) (0.16.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna>=2.0.0->pykeen==1.11.1->ontoaligner) (1.18.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna>=2.0.0->pykeen==1.11.1->ontoaligner) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna>=2.0.0->pykeen==1.11.1->ontoaligner) (2.0.45)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.56.0->ontoaligner) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.56.0->ontoaligner) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==1.56.0->ontoaligner) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->ontoaligner) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pykeen==1.11.1->ontoaligner) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pykeen==1.11.1->ontoaligner) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0.0,>=2.8.0->ontoaligner) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->pykeen==1.11.1->ontoaligner) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->pykeen==1.11.1->ontoaligner) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0.0,>=2.8.0->ontoaligner) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->ontoaligner) (1.22.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen==1.11.1->ontoaligner) (1.3.10)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen==1.11.1->ontoaligner) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen==1.11.1->ontoaligner) (1.1.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0

# %% [markdown]
# Import necessary modules from the ontoaligner package

# %%
from ontoaligner.ontology import GraphTripleOMDataset          # Handles ontology data collection in graph triple format
from ontoaligner.encoder import GraphTripleEncoder             # Encodes graph triple data into model-consumable format
from ontoaligner.aligner import ConvEAligner                   # Alignment model based on ConvE (Knowledge Graph Embedding)
from ontoaligner.postprocess import graph_postprocessor        # Applies post-processing to improve alignment quality
from ontoaligner.utils import metrics, xmlify                  # Utilities for evaluation and XML export
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# INFO:pykeen.utils:Using opt_einsum

# %% [markdown]
# ### Step 1: Initialize ontology matching task

# %%
task = GraphTripleOMDataset()
task.ontology_name = "Customer-Guests"                             # Assign a name for the ontology matching task
print("task:", task)
# Example output: task: Track: GraphTriple, Source-Target sets: Mouse-Human
# Out:
# task: Track: GraphTriple, Source-Target sets: Customer-Guests

# %% [markdown]
# ### Step 2: Load source, target, and reference ontologies

# %%
dataset = task.collect(
    source_ontology_path="/content/drive/MyDrive/assets/integration_test_data/customers.xml",      # Path to source ontology
    target_ontology_path="/content/drive/MyDrive/assets/integration_test_data/guests.xml",      # Path to target ontology
    reference_matching_path="/content/drive/MyDrive/assets/integration_test_data/reference.xml" # Path to ground-truth reference alignments
)
print("dataset key-values:", dataset.keys())
# Example output: dict_keys(['dataset-info', 'source', 'target', 'reference'])
print("dataset [sorce]: ", dataset["source"][:3])
print("dataset [target]: ", dataset["target"][:3])
print("dataset [reference]: ", dataset["reference"][:3])
# Out:
# 100%|██████████| 41/41 [00:00<00:00, 32197.43it/s]
# dataset key-values: dict_keys(['dataset-info', 'source', 'target', 'reference'])
# dataset [sorce]:  [{'subject': ('http://example.org/ontology/customer#birth_day', 'birth_day'), 'predicate': ('http://www.w3.org/2000/01/rdf-schema#range', 'range'), 'object': ('http://www.w3.org/2001/XMLSchema#string', 'string'), 'subject_is_class': False, 'object_is_class': False}, {'subject': ('http://example.org/ontology/customer#a2ab1195-6e12-4ba4-9550-94cd8e9a9433', 'a2ab1195-6e12-4ba4-9550-94cd8e9a9433'), 'predicate': ('http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'type'), 'object': ('http://example.org/ontology/customer#Customer', 'Customer'), 'subject_is_class': False, 'object_is_class': True}, {'subject': ('http://example.org/ontology/customer#Customer', 'Customer'), 'predicate': ('http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'type'), 'object': ('http://www.w3.org/2002/07/owl#Class', 'Class'), 'subject_is_class': True, 'object_is_class': False}]
# dataset [target]:  [{'subject': ('http://example.org/ontology/guest#d09774ee-a1e0-446e-b200-142f4009bf41', 'd09774ee-a1e0-446e-b200-142f4009bf41'), 'predicate': ('http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'type'), 'object': ('http://example.org/ontology/guest#Guest', 'Guest'), 'subject_is_class': False, 'object_is_class': True}, {'subject': ('http://example.org/ontology/guest#lastName', 'lastName'), 'predicate': ('http://www.w3.org/2000/01/rdf-schema#domain', 'domain'), 'object': ('http://example.org/ontology/guest#Guest', 'Guest'), 'subject_is_class': False, 'object_is_class': True}, {'subject': ('http://example.org/ontology/guest#fd3257f3-8cc8-482d-9d95-ccd6b66ee7b6', 'fd3257f3-8cc8-482d-9d95-ccd6b66ee7b6'), 'predicate': ('http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'type'), 'object': ('http://example.org/ontology/guest#Guest', 'Guest'), 'subject_is_class': False, 'object_is_class': True}]
# dataset [reference]:  [{'source': 'http://example.org/ontology/customer#birth_day', 'target': 'http://example.org/ontology/guest#birthDate', 'relation': '='}, {'source': 'http://example.org/ontology/customer#email', 'target': 'http://example.org/ontology/guest#emailAddress', 'relation': '='}, {'source': 'http://example.org/ontology/customer#first_name', 'target': 'http://example.org/ontology/guest#firstName', 'relation': '='}]

# %% [markdown]
# Print a sample of the parsed source ontology data

# %%
print("Sample source ontology:", dataset['source'][0])
# Out:
# Sample source ontology: {'subject': ('http://example.org/ontology/customer#birth_day', 'birth_day'), 'predicate': ('http://www.w3.org/2000/01/rdf-schema#range', 'range'), 'object': ('http://www.w3.org/2001/XMLSchema#string', 'string'), 'subject_is_class': False, 'object_is_class': False}

# %% [markdown]
# ### Step 3: Encode the dataset into a format suitable for the aligner

# %%
encoder = GraphTripleEncoder()
encoded_dataset = encoder(**dataset)                           # Transforms raw ontology triples into embedding-compatible format

# %% [markdown]
# ### Step 4: Define training parameters for the ConvE aligner

# %%
kge_params = {
    'device': 'cuda',                  # Device to use ('cpu' or 'cuda')
    'embedding_dim': 300,            # Size of embedding vectors
    'num_epochs': 50,                # Total number of training epochs
    'train_batch_size': 128,         # Batch size for training
    'eval_batch_size': 64,           # Batch size for evaluation
    'num_negs_per_pos': 5,           # Number of negative samples for each positive sample
    'random_seed': 42,               # Seed for reproducibility
}

# %% [markdown]
# ### Step 5: Initialize and train the aligner model
# For faster training connect to runtime with T4 (GPU)

# %%
aligner = ConvEAligner(**kge_params)
matchings = aligner.generate(input_data=encoded_dataset)       # Generate predicted alignments between source and target ontologies
# Out:
# INFO:pykeen.pipeline.api:Using device: cuda
# INFO:pykeen.nn.modules:Resolving None * None * None = 300.
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# Training epochs on cuda:0:   0%|          | 0/50 [00:00<?, ?epoch/s]
# INFO:pykeen.triples.triples_factory:Creating inverse triples.
# INFO:pykeen.training.training_loop:Dropping last (incomplete) batch each epoch (1/1 (100.00%) batches).
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/1.00 [00:00<?, ?batch/s]
# WARNING:pykeen.pipeline.api:Found evaluation_factory.create_inverse_triples=True which is ignored for evaluation factories. The model itself determines whether inverse relations are used in head prediction. Here, the model was created with training.create_inverse_triples=True
# Evaluating on cuda:0:   0%|          | 0.00/83.0 [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.11s seconds

# %% [markdown]
# ### Step 6: Post-process the predicted matchings
# Filters matchings using a similarity threshold (e.g., 0.5)

# %%
processed_matchings = graph_postprocessor(predicts=matchings, threshold=0.5)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 14563.56it/s]

# %% [markdown]
# ## Visualise results using pandas DataFrame's

# %%
import pandas as pd
import numpy as np
df_matchings = pd.DataFrame(matchings)

# Build lookup dictionary
lookup = {
    (d["source"], d["target"]): d["score"]
    for d in processed_matchings
}

# Assign new column
df_matchings["post_processed_score"] = df_matchings.apply(
    lambda row: lookup.get((row["source"], row["target"])),
    axis=1
)

ref_df = pd.DataFrame(dataset["reference"])

# Convert "=" → 1.0, everything else → NaN (or 0.0 if you prefer)
ref_df["true_match"] = np.where(ref_df["relation"] == "=", 1.0, np.nan)

df_matchings = df_matchings.merge(
    ref_df[["source", "target", "true_match"]],
    on=["source", "target"],
    how="left"
)

df_matchings
# Out:
#                                           source  \
# 0  http://example.org/ontology/customer#Customer
#
#                                     target    score post_processed_score  \
# 0  http://example.org/ontology/guest#Guest  0.03763                 None
#
#    true_match
# 0         NaN

# %% [markdown]
# ### Step 7: Evaluate matchings before and after post-processing

# %%
evaluation = metrics.evaluation_report(predicts=matchings, references=dataset['reference'])
print("Matching Evaluation Report:\n", evaluation)

evaluation = metrics.evaluation_report(predicts=processed_matchings, references=dataset['reference'])
print("Matching Evaluation Report -- after post-processing:\n", evaluation)
# Out:
# Matching Evaluation Report:
#  {'intersection': 0, 'precision': 0.0, 'recall': 0.0, 'f-score': 0, 'predictions-len': 1, 'reference-len': 5}
# Matching Evaluation Report -- after post-processing:
#  {'intersection': 0, 'precision': 0, 'recall': 0.0, 'f-score': 0, 'predictions-len': 0, 'reference-len': 5}

# %% [markdown]
# ### Step 8: Convert processed matchings to XML format and save to file

# %%
xml_str = xmlify.xml_alignment_generator(matchings=processed_matchings)
with open("matchings.xml", "w", encoding="utf-8") as xml_file:
    xml_file.write(xml_str)
